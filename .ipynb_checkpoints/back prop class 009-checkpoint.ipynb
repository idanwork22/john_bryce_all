# %%
import numpy as np

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def s(x):
    return 1/(1+np.exp(-x))

# %%
s(0)
# Out:
# 0.5

# %%
f = lambda x: s(x)

# %%
x1 = 0.1
x2 = 0.2
w1 = 0.1
w2 = 0.2
w3 = 0.3
w4 = 0.4
w5 = 0.5
w6 = 0.6
w7 = 0.7
w8 = 0.8
b1 = 0.5
b2 = 0.6
out1 = 0.01
out2 = 0.99

# %%
y1 = x1*w1 + x2*w2 + b1
s1 = f(y1)
print(y1, s1)
# Out:
# 0.55 0.6341355910108007
