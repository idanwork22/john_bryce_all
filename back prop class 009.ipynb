# %%
import numpy as np

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def s(x):
    return 1/(1+np.exp(-x))

# %%
s(0)
# Out:
# 0.5

# %%
f = lambda x: s(x)

# %%
x1 = 0.1
x2 = 0.2
w1 = 0.1
w2 = 0.2
w3 = 0.3
w4 = 0.4
w5 = 0.5
w6 = 0.6
w7 = 0.7
w8 = 0.8
b1 = 0.5
b2 = 0.6
out1 = 0.01
out2 = 0.99

# %%
y1 = x1*w1 + x2*w2 + b1
s1 = f(y1)
print(y1, format(s1,".2f"))
# Out:
# 0.55 0.63

# %%
y2 = x1*w3 + x2*w4 + b1
s2 = f(y2)
print(y2, format(s2,".2f"))
# Out:
# 0.61 0.65

# %%
y3 = s1*w5 + s2*w6 + b2
s3 = f(y3)
print(format(y3,".2f"), format(s3,".2f"))
# Out:
# 1.31 0.79

# %%
y4 = s1*w7 + s2*w8 + b2
s4 = f(y4)
print(format(y4,".2f"), format(s4,".2f"))
# Out:
# 1.56 0.83

# %%
E = 0.5*(0.01-s3)**2 + 0.5*(0.99-s4)**2
format(E,".3f")
# Out:
# '0.315'
