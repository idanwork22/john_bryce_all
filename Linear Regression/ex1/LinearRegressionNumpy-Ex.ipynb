# %% [markdown]
# # Lab - Least Squares Regression

# %%
import numpy as np
import matplotlib.pylab as plt

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([15,32,66,45,90,153,170,200])

# %%
# %matplotlib inline

# %% [markdown]
# Create a scatter graph

# %%
plt.scatter(x=x,y=y)

# %% [markdown]
# To create a linear regression model we need to build a simple linear function:

# %% [markdown]
# # Y = mX + b

# %% [markdown]
# ## $m = \frac{N * \sum (xy) - \sum (x)\sum (y)}{N * \sum X^{2}-(\sum x)^{2}}$

# %% [markdown]
# ## $b = \frac{\sum y - m\sum x}{N}$

# %% [markdown]
# Compute all the elements

# %%
m_up = (len(x)*np.sum(x*y) -np.sum(x)*np.sum(y))
m_down = len(x)*np.sum(x**2)-(np.sum(x)**2)
m = m_up /m_down

m_up
# Out:
# 9164

# %%
m_down = len(x)*np.sum(x**2)-(np.sum(x)**2)
m_down
# Out:
# 336

# %%
m = m_up /m_down
m
# Out:
# 27.273809523809526

# %%
b= (np.sum(y)- m*np.sum(x))/len(x)
b
# Out:
# -26.35714285714286

# %% [markdown]
# Compute the slope (m) in one line

# %% [markdown]
# Compute b

# %% [markdown]
# Write a function fn - F(x)

# %%
def fn(x):
    return 27.27*x -26.35

# %% [markdown]
# Draw graph to see the result, combine the scatter and the regression line

# %%
plt.scatter(x,y)
plt.plot(np.arange(10),fn(np.arange(10)))

# %% [markdown]
# Write a function to generate linear regression model based on 2 vectors
# <br/>
# use a closure to generate a function dynamically

# %%
def getlinear(x,y):
    def inner(x1):
        return m*x1 + b
    
    m_up = (len(x)*np.sum(x*y) -np.sum(x)*np.sum(y))
    m_down = len(x)*np.sum(x**2)-(np.sum(x)**2)
    m = m_up /m_down
    b= (np.sum(y)- m*np.sum(x))/len(x)
    return inner

# %% [markdown]
# Test your function

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([15,32,66,45,90,153,170,200])

# %%
my_model = getlinear(x,y)

# %%
my_model(6)
# Out:
# 137.2857142857143

# %% [markdown]
# Use linear algebra package from numpy to do the same task
