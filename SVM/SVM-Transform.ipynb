# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("svmtrans.csv")

# %%
df.head()
# Out:
#       A     B  C
# 0 -69.0   6.0  1
# 1 -23.0  12.0  1
# 2 -23.0 -18.0  1
# 3  11.5   3.6  1
# 4  23.0  -6.0  1

# %%
plt.axhline(0,color='red') # x = 0
plt.axvline(0,color='red') # y = 0

plt.scatter(df['A'],df['B'],c=df['C'])

# %%
import math

# %%
df['X'] = df['A']**2

# %%
df['Y'] = math.sqrt(2)*df['A']*df['B']

# %%
df['Z'] = df['B']**2

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

ax1.scatter(df['X'], df['Y'], df['Z'],c=df['C'])
# Out:
# <div id='d2b6ab48-a0e7-451a-9883-8d28a582a3f8'></div>

# %%
# %matplotlib widget
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.

# %%
# !pip install nodejs
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install jupyter-matplotlib
# Out:
# Collecting nodejs
#   Downloading nodejs-0.1.1.tar.gz (2.3 kB)
# Collecting optional-django==0.1.0
#   Downloading optional-django-0.1.0.tar.gz (9.5 kB)
# Building wheels for collected packages: nodejs, optional-django
#   Building wheel for nodejs (setup.py): started
#   Building wheel for nodejs (setup.py): finished with status 'done'
#   Created wheel for nodejs: filename=nodejs-0.1.1-py3-none-any.whl size=3498 sha256=eba1690de121f6548df66cbb82420cd8b4b2d347b07a3365ca5e29f692021f91
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\b3\ce\d8\40f8634e964582985b2c4560cbba06d4f50d3da980fccd0497
#   Building wheel for optional-django (setup.py): started
#   Building wheel for optional-django (setup.py): finished with status 'done'
#   Created wheel for optional-django: filename=optional_django-0.1.0-py3-none-any.whl size=9985 sha256=ad218dd36bcf8b76b801d434bab0751057a452164b6ff5746d889af1f5eb5beb
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\3b\42\9c\10c5c4021a4edf8416f18e88b427b92e99f187e61e15e08100
# Successfully built nodejs optional-django
# Installing collected packages: optional-django, nodejs
# Successfully installed nodejs-0.1.1 optional-django-0.1.0
# Building jupyterlab assets (build:prod:minimize)
# Building jupyterlab assets (build:prod:minimize)
