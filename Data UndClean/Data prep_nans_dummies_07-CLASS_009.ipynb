# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
## ADD SEED!
np.random.seed(47)
arr = np.random.randint(10,20,(20,3))

# %%
df = pd.DataFrame(arr,columns=['A','B','C'])

# %%
df.head()
# Out:
#     A   B   C
# 0  17  16  17
# 1  18  18  13
# 2  10  17  10
# 3  17  17  11
# 4  17  12  12

# %%
df['A'][df['A']%7 == 0] = np.NAN
df['B'][df['B']%5 == 0] = np.NAN
df['C'][df['C']%4 == 0] = np.NAN
# Out:
# <ipython-input-5-15ee8481e302>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['B'][df['B']%5 == 0] = np.NAN
# <ipython-input-5-15ee8481e302>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['C'][df['C']%4 == 0] = np.NAN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       17 non-null     float64
#  1   B       18 non-null     float64
#  2   C       15 non-null     float64
# dtypes: float64(3)
# memory usage: 608.0 bytes

# %%
df.A
# Out:
# 0     17.0
# 1     18.0
# 2     10.0
# 3     17.0
# 4     17.0
# 5     11.0
# 6     18.0
# 7     19.0
# 8     10.0
# 9     10.0
# 10     NaN
# 11    15.0
# 12    16.0
# 13    15.0
# 14    18.0
# 15    13.0
# 16     NaN
# 17     NaN
# 18    12.0
# 19    10.0
# Name: A, dtype: float64

# %%
# df.A.fillna(200)
df.A.fillna({10:2000,16:3000})
# Out:
# 0       17.0
# 1       18.0
# 2       10.0
# 3       17.0
# 4       17.0
# 5       11.0
# 6       18.0
# 7       19.0
# 8       10.0
# 9       10.0
# 10    2000.0
# 11      15.0
# 12      16.0
# 13      15.0
# 14      18.0
# 15      13.0
# 16    3000.0
# 17       NaN
# 18      12.0
# 19      10.0
# Name: A, dtype: float64

# %%
df.A
# Out:
# 0     17.0
# 1     18.0
# 2     10.0
# 3     17.0
# 4     17.0
# 5     11.0
# 6     18.0
# 7     19.0
# 8     10.0
# 9     10.0
# 10     NaN
# 11    15.0
# 12    16.0
# 13    15.0
# 14    18.0
# 15    13.0
# 16     NaN
# 17     NaN
# 18    12.0
# 19    10.0
# Name: A, dtype: float64

# %%
df.A.mean()
# Out:
# 14.470588235294118

# %%
df.A.var()
# Out:
# 11.264705882352942

# %%
df.A.std()
# Out:
# 3.356293473811988

# %%
df.A.mode()
# Out:
# 0    10.0
# dtype: float64

# %%
df.A.median()
# Out:
# 15.0

# %%
s1 = pd.Series(np.random.normal(5,10,100))
df['B'].fillna(s1,inplace=True)

# %%
df.B.hist()
# Out:
# <AxesSubplot:>

# %%
print(df.A)
print(df.A.fillna(method='ffill'))
# Out:
# 0     17.0
# 1     18.0
# 2     10.0
# 3     17.0
# 4     17.0
# 5     11.0
# 6     18.0
# 7     19.0
# 8     10.0
# 9     10.0
# 10     NaN
# 11    15.0
# 12    16.0
# 13    15.0
# 14    18.0
# 15    13.0
# 16     NaN
# 17     NaN
# 18    12.0
# 19    10.0
# Name: A, dtype: float64
# 0     17.0
# 1     18.0
# 2     10.0
# 3     17.0
# 4     17.0
# 5     11.0
# 6     18.0
# 7     19.0
# 8     10.0
# 9     10.0
# 10    10.0
# 11    15.0
# 12    16.0
# 13    15.0
# 14    18.0
# 15    13.0
# 16    13.0
# 17    13.0
# 18    12.0
# 19    10.0
# Name: A, dtype: float64

# %%
df.A
# Out:
# 0     17.0
# 1     18.0
# 2     10.0
# 3     17.0
# 4     17.0
# 5     11.0
# 6     18.0
# 7     19.0
# 8     10.0
# 9     10.0
# 10     NaN
# 11    15.0
# 12    16.0
# 13    15.0
# 14    18.0
# 15    13.0
# 16     NaN
# 17     NaN
# 18    12.0
# 19    10.0
# Name: A, dtype: float64

# %%
df.A.interpolate()
# Out:
# 0     17.000000
# 1     18.000000
# 2     10.000000
# 3     17.000000
# 4     17.000000
# 5     11.000000
# 6     18.000000
# 7     19.000000
# 8     10.000000
# 9     10.000000
# 10    12.500000
# 11    15.000000
# 12    16.000000
# 13    15.000000
# 14    18.000000
# 15    13.000000
# 16    12.666667
# 17    12.333333
# 18    12.000000
# 19    10.000000
# Name: A, dtype: float64

# %%
#take pupils1 from pandas folder
df = pd.read_csv("pupils.csv")

# %%
df.head()
# Out:
#    Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0  adar    6      SP     113      30   70   16700      7       6     1   M
# 1  agam    6      GR     172      71   92    9200      5       4     2   F
# 2   avi    7     ISR     143      58   82   12000      3       7     1   M
# 3  dani    7      US     160      70   90   15000      4       4     2   M
# 4  dina    7     ISR     110      26   64   10000      6       8     1   F

# %%
df.City.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-76f3f64fbb78> in <module>
# ----> 1 df.City.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'City'

# %%
df.City.unique()
# Out:
# array(['TLV', 'Haifa', 'Aco'], dtype=object)

# %%
df.City.nunique()
# Out:
# 3

# %%
pd.Categorical(df.City)
# Out:
# ['TLV', 'Haifa', 'Aco', 'TLV', 'Haifa', 'Aco', 'TLV', 'Haifa', 'Haifa']
# Categories (3, object): ['Aco', 'Haifa', 'TLV']

# %%
df['Gender'] = pd.Categorical(df['Gender']).codes

# %%
df
# Out:
#     Name  Gender   City  Height  Weight  Avg Grades
# 0   adar       1    TLV     113      30          70
# 1   agam       0  Haifa     172      71          92
# 2    avi       1    Aco     143      58          82
# 3   dani       1    TLV     160      70          90
# 4   dina       0  Haifa     110      26          64
# 5  efrat       0    Aco     115      33          75
# 6   ehud       1    TLV     155      66          85
# 7    eli       1  Haifa     155      61          84
# 8  ester       0  Haifa     130      48          79

# %%
pd.Categorical(df['City']).codes
# Out:
# array([2, 1, 0, 2, 1, 0, 2, 1, 1], dtype=int8)

# %%
pd.get_dummies(df['City'])
# Out:
#    Aco  Haifa  TLV
# 0    0      0    1
# 1    0      1    0
# 2    1      0    0
# 3    0      0    1
# 4    0      1    0
# 5    1      0    0
# 6    0      0    1
# 7    0      1    0
# 8    0      1    0

# %%
df2 = pd.get_dummies(df,columns=['City'],drop_first=True)

# %%
df2
# Out:
#     Name  Gender  Height  Weight  Avg Grades  City_Haifa  City_TLV
# 0   adar       1     113      30          70           0         1
# 1   agam       0     172      71          92           1         0
# 2    avi       1     143      58          82           0         0
# 3   dani       1     160      70          90           0         1
# 4   dina       0     110      26          64           1         0
# 5  efrat       0     115      33          75           0         0
# 6   ehud       1     155      66          85           0         1
# 7    eli       1     155      61          84           1         0
# 8  ester       0     130      48          79           1         0
