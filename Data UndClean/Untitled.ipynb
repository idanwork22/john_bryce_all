# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
d = {'col1': [1 ,np.nan,2], 'col2': [3, 4,2]}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    col1  col2
# 0   1.0     3
# 1   NaN     4
# 2   2.0     2

# %%
df.col1.fillna(method='ffill', inplace=True)
df
# Out:
#    col1  col2
# 0   1.0     3
# 1   1.0     4
# 2   2.0     2

# %%
df.index = ['1','11','111']

# %%
df
# Out:
#      col1  col2
# 1     1.0     3
# 11    1.0     4
# 111   2.0     2

# %%
df.index.str.len().values.mean()
# Out:
# 2.0
