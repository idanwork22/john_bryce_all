# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from scipy.stats import skew
skew([1,2,3,4,5])
# Out:
# 0.0

# %%
skew([-111,2,3,4,5])
# Out:
# -1.498213426537613

# %%
skew([1,2,3,4,50])
# Out:
# 1.4896509056341305

# %%
df = pd.read_csv('pupils-ex.csv')

# %%
df
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type  \
# 0      adar    6      SP   113.0      30   70   16700      7       6     1
# 1      agam    6      GR   172.0      71   92    9200      5       4     2
# 2       avi    7     NaN   143.0      58   82   12000      3       7     1
# 3      dani    7      US     NaN      70   90   15000      4       4     2
# 4      dina    7     ISR   110.0      26   64   10000      6       8     1
# 5     efrat    7     NaN   115.0      33   75    8000      5       5     3
# 6      ehud    8     ISR   155.0      66   85   18000      2       7     1
# 7       eli    8     NaN   155.0      61   84    8900      7      10     2
# 8     ester    8     ISR     NaN      48   79   19600      2       4     1
# 9   evyatar    8     NaN   110.0      34   72    7600      3       4     1
# 10   itamar    8      EN   110.0      30   71   27000      2       5     2
# 11     liel    8     NaN   142.0      55   84   24000      2       7     1
# 12   lilach    9     ISR   192.0      88   94   23000      5       6     2
# 13      mia    9     NaN     NaN      49   82   12800      4       5     3
# 14   michal    9      US   132.0      53   79   20400      5       7     3
# 15    moshe    9      GR   128.0      43   80   42000      6       5     3
# 16     noya    9      SP    90.0      27   68   18200      6       5     1
# 17     ofer   10     NaN     NaN      34   71    9300      4       8     1
# 18     ohad   10     ISR   159.0      64   83   12700      4       8     1
# 19     omer   10      US   162.0      68   87   34500      6       8     2
# 20     orit   44      US   123.0      40   78   18900      3       7     3
# 21     orit   11     NaN   175.0      73   89   54100      4       3     2
# 22     rina   11      EN     NaN      31   73   30000      2       5     3
# 23    shely   11     ISR   148.0      60   86    8000      4       3     1
# 24    talya   12      FR   167.0      67   89   10900      6       6     2
# 25    tomer   12     NaN   128.0      53   82   45000      5       4     3
# 26      udi   13      FR     NaN      55   85   35000      7       6     2
# 27    yafit   13      FR   180.0      90   93   12800      2       4     1
# 28     yoav   13      EN   120.0      36   74   17300      5       8     3
# 29     yosi   14      SP   110.0      32   74   22000      5       6     1
#
#    gen  namelen
# 0    M        4
# 1    F        4
# 2    M        3
# 3    M        4
# 4    F        4
# 5    F        5
# 6    M        4
# 7    M        3
# 8    F        5
# 9    M        7
# 10   M        6
# 11   M        4
# 12   F        6
# 13   F        3
# 14   F        6
# 15   M        5
# 16   F        4
# 17   M        4
# 18   M        4
# 19   F        4
# 20   F        4
# 21   F        4
# 22   F        4
# 23   F        5
# 24   F        5
# 25   M        5
# 26   M        3
# 27   F        5
# 28   M        4
# 29   M        4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     30 non-null     object
#  1   Age      30 non-null     int64
#  2   Country  21 non-null     object
#  3   Height   24 non-null     float64
#  4   Weight   30 non-null     int64
#  5   avg      30 non-null     int64
#  6   income   30 non-null     int64
#  7   rooms    30 non-null     int64
#  8   family   30 non-null     int64
#  9   type     30 non-null     int64
#  10  gen      30 non-null     object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.7+ KB

# %%
df.isnull().sum().sum()
# Out:
# 15

# %%
df.describe()
# Out:
#              Age      Height     Weight        avg        income      rooms  \
# count  30.000000   24.000000  30.000000  30.000000     30.000000  30.000000
# mean   10.566667  139.125000  51.500000  80.500000  20096.666667   4.366667
# std     6.688556   27.291203  18.104581   7.942683  11943.270601   1.629117
# min     6.000000   90.000000  26.000000  64.000000   7600.000000   2.000000
# 25%     8.000000  114.500000  34.000000  74.000000  11175.000000   3.000000
# 50%     9.000000  137.000000  53.000000  82.000000  17650.000000   4.500000
# 75%    11.000000  159.750000  65.500000  85.750000  23750.000000   5.750000
# max    44.000000  192.000000  90.000000  94.000000  54100.000000   7.000000
#
#           family       type
# count  30.000000  30.000000
# mean    5.833333   1.833333
# std     1.743626   0.833908
# min     3.000000   1.000000
# 25%     4.250000   1.000000
# 50%     6.000000   2.000000
# 75%     7.000000   2.750000
# max    10.000000   3.000000

# %%
df.corr()
# Out:
#              Age    Height    Weight       avg    income     rooms    family  \
# Age     1.000000 -0.072604 -0.072187 -0.005517  0.096242 -0.133651  0.100037
# Height -0.072604  1.000000  0.973898  0.948284  0.092652 -0.132928 -0.031659
# Weight -0.072187  0.973898  1.000000  0.959074  0.091562 -0.084762 -0.125074
# avg    -0.005517  0.948284  0.959074  1.000000  0.145275 -0.065290 -0.212886
# income  0.096242  0.092652  0.091562  0.145275  1.000000  0.062980 -0.241287
# rooms  -0.133651 -0.132928 -0.084762 -0.065290  0.062980  1.000000  0.289322
# family  0.100037 -0.031659 -0.125074 -0.212886 -0.241287  0.289322  1.000000
# type    0.295721 -0.035144 -0.065094  0.075489  0.360018  0.173446 -0.043478
#
#             type
# Age     0.295721
# Height -0.035144
# Weight -0.065094
# avg     0.075489
# income  0.360018
# rooms   0.173446
# family -0.043478
# type    1.000000

# %%
df.Height.fillna(df.Height.mean(),inplace=True)

# %%
df.Age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.loc[df.Age > 12,'Age'] = 12

# %%
df.loc[df.Height.isnull(),'Height'] = df.Age*12

# %%
ls = [2,4,6,8,10]*10
for k,v in df.iterrows():
    if np.isnan(v.Height):
            df.loc[k,'Height'] = ls[v.Age]

# %%
df.drop(df.loc[df.Age <= 8].index,inplace=True)

# %%
df.drop(['type'],axis=1,inplace=True)

# %%
df['gen'].replace({'M':1 , 'F':2},inplace=True)

# %%
df['namelen']=df.Name.apply(len)

# %%
def myop(inc):
    if inc < 10000:
        return 1
    else:
        if inc < 30000:
            return 2
        else:
            return 3

# %%
df["new_inc2"] = df["income"].apply(lambda x: 1 if x<10000 else (2 if x <30000 else 3))

# %%
np.isnan(op_list).all()
# Out:
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: new_inc, dtype: bool

# %%
df['new_inc'] = df.income.apply(myop)

# %%
df.head()
# Out:
#       Name  Age Country  Height  Weight  avg  income  rooms  family  type gen  \
# 12  lilach    9     ISR   192.0      88   94   23000      5       6     2   F
# 13     mia    9     NaN     NaN      49   82   12800      4       5     3   F
# 14  michal    9      US   132.0      53   79   20400      5       7     3   F
# 15   moshe    9      GR   128.0      43   80   42000      6       5     3   M
# 16    noya    9      SP    90.0      27   68   18200      6       5     1   F
#
#     namelen  new_inc  new_inc2
# 12        6        2         2
# 13        3        2         2
# 14        6        2         2
# 15        5        3         3
# 16        4        2         2

# %%
df.income.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.income.plot.bar()
# Out:
# <AxesSubplot:>

# %%
sb.countplot(df['income'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
sb.distplot(df['income'],kde=False,bins=30)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='income'>

# %%
def myop2(r):
    print("=====",r.Age , r.income)
    return r.Age*r.income

# %%
df['new2'] = df.apply(myop2,axis=1)
# Out:
# ===== 6 16700
# ===== 6 9200
# ===== 7 12000
# ===== 7 15000
# ===== 7 10000
# ===== 7 8000
# ===== 8 18000
# ===== 8 8900
# ===== 8 19600
# ===== 8 7600
# ===== 8 27000
# ===== 8 24000
# ===== 9 23000
# ===== 9 12800
# ===== 9 20400
# ===== 9 42000
# ===== 9 18200
# ===== 10 9300
# ===== 10 12700
# ===== 10 34500
# ===== 44 18900
# ===== 11 54100
# ===== 11 30000
# ===== 11 8000
# ===== 12 10900
# ===== 12 45000
# ===== 13 35000
# ===== 13 12800
# ===== 13 17300
# ===== 14 22000

# %%
np.digitize(df.Height, [110,130,150,160], right=True)
# Out:
# array([1, 4, 2, 0, 0, 1, 3, 3, 0, 0, 0, 2, 4, 0, 2, 1, 0, 0, 3, 4, 1, 4,
#        0, 2, 4, 1, 0, 4, 1, 0])

# %%
pd.get_dummies(df.type).head()
# Out:
#    1  2  3
# 0  1  0  0
# 1  0  1  0
# 2  1  0  0
# 3  0  1  0
# 4  1  0  0

# %%
pd.cut(df.Height,bins=3,labels=['S','M','L'])
# Out:
# 0     M
# 1     L
# 2     L
# 3     S
# 4     M
# 5     M
# 6     L
# 7     L
# 8     S
# 9     M
# 10    M
# 11    L
# 12    L
# 13    S
# 14    L
# 15    M
# 16    M
# 17    S
# 18    L
# 19    L
# 20    M
# 21    L
# 22    S
# 23    L
# 24    L
# 25    M
# 26    S
# 27    L
# 28    M
# 29    M
# Name: Height, dtype: category
# Categories (3, object): [S < M < L]

# %%
pd.qcut(df.Height,q=[0,0.1,0.8,1],labels=['S','M','L'])
