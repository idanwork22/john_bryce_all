# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
arr = np.random.randint(10,20,(20,3))

# %%
df = pd.DataFrame(arr,columns=['A','B','C'])

# %%
df['A'][df['A']%7 == 0] = np.NAN
df['B'][df['B']%5 == 0] = np.NAN
df['C'][df['C']%4 == 0] = np.NAN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# A    17 non-null float64
# B    14 non-null float64
# C    14 non-null float64
# dtypes: float64(3)
# memory usage: 560.0 bytes

# %%
#df.A.fillna(100,inplace=True)
df.A.fillna(200)
df.A.fillna({7:2,1:3})
# Out:
# 0     11.0
# 1      3.0
# 2     10.0
# 3     13.0
# 4      NaN
# 5     17.0
# 6     10.0
# 7     10.0
# 8     12.0
# 9     12.0
# 10    16.0
# 11     NaN
# 12    18.0
# 13    11.0
# 14    16.0
# 15    10.0
# 16    16.0
# 17    19.0
# 18    15.0
# 19    15.0
# Name: A, dtype: float64

# %%
df.A.mean()
# Out:
# 13.588235294117647

# %%
df.A.var()
# Out:
# 9.50735294117647

# %%
df.A.std()
# Out:
# 3.0833995753350667

# %%
df.A.mode()
# Out:
# 0    10.0
# dtype: float64

# %%
df.A.median()
# Out:
# 13.0

# %%
s1 = pd.Series(np.random.normal(5,10,100))
df['B'].fillna(s1,inplace=True)

# %%
df.B.hist()

# %%
print(df.A)
print(df.A.fillna(method='ffill'))
# Out:
# 0     11.0
# 1     15.0
# 2     10.0
# 3     10.0
# 4      NaN
# 5     17.0
# 6      NaN
# 7     19.0
# 8     17.0
# 9     17.0
# 10     NaN
# 11    17.0
# 12     NaN
# 13    16.0
# 14    18.0
# 15    18.0
# 16    11.0
# 17    17.0
# 18     NaN
# 19    15.0
# Name: A, dtype: float64
# 0     11.0
# 1     15.0
# 2     10.0
# 3     10.0
# 4     10.0
# 5     17.0
# 6     17.0
# 7     19.0
# 8     17.0
# 9     17.0
# 10    17.0
# 11    17.0
# 12    17.0
# 13    16.0
# 14    18.0
# 15    18.0
# 16    11.0
# 17    17.0
# 18    17.0
# 19    15.0
# Name: A, dtype: float64

# %%
df.A.interpolate()
# Out:
# 0     11.0
# 1     15.0
# 2     10.0
# 3     10.0
# 4     13.5
# 5     17.0
# 6     18.0
# 7     19.0
# 8     17.0
# 9     17.0
# 10    17.0
# 11    17.0
# 12    16.5
# 13    16.0
# 14    18.0
# 15    18.0
# 16    11.0
# 17    17.0
# 18    16.0
# 19    15.0
# Name: A, dtype: float64

# %%
df = pd.read_csv("pupils1.csv")

# %%
df.head()
# Out:
#     Name Gender   City  Height  Weight  Avg Grades
# 0   dina      F  Haifa     110      26          64
# 1   adar      M    TLV     113      30          70
# 2  efrat      F    Aco     115      33          45
# 3  ester      F  Haifa     130      48          90
# 4    avi      M    Aco     143      58          89

# %%
df.City.value_counts()
# Out:
# Haifa    4
# TLV      3
# Aco      2
# Name: City, dtype: int64

# %%
df.City.unique()
# Out:
# array(['Haifa', 'TLV', 'Aco'], dtype=object)

# %%
df.City.nunique()
# Out:
# 3

# %%
pd.Categorical(df.City)
# Out:
# [Haifa, TLV, Aco, Haifa, Aco, Haifa, TLV, TLV, Haifa]
# Categories (3, object): [Aco, Haifa, TLV]

# %%
df['Gender'] = pd.Categorical(df['Gender']).codes

# %%
pd.get_dummies(df['City'])
# Out:
#    Aco  Haifa  TLV
# 0    0      1    0
# 1    0      0    1
# 2    1      0    0
# 3    0      1    0
# 4    1      0    0
# 5    0      1    0
# 6    0      0    1
# 7    0      0    1
# 8    0      1    0

# %%
df2 = pd.get_dummies(df,columns=['City'],drop_first=True)

# %%
df2
# Out:
#     Name Gender  Height  Weight  Avg Grades  City_Haifa  City_TLV
# 0   dina      F     110      26          64           1         0
# 1   adar      M     113      30          70           0         1
# 2  efrat      F     115      33          45           0         0
# 3  ester      F     130      48          90           1         0
# 4    avi      M     143      58          89           0         0
# 5    eli      M     155      61          76           1         0
# 6   ehud      M     155      66          55           0         1
# 7   dani      M     160      70          90           0         1
# 8   agam      F     172      71          60           1         0
