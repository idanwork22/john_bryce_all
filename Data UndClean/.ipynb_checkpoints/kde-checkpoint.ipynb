# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
arr = np.loadtxt("datakde.txt")

# %%
plt.hist(arr,bins=30)
# Out:
# (array([ 1.,  1.,  1.,  1.,  3.,  2.,  4.,  4.,  1.,  5.,  5.,  7.,  5.,
#          8.,  8., 12.,  6.,  8.,  2.,  0.,  0.,  0.,  1.,  5.,  4.,  0.,
#          5.,  0.,  0.,  1.]),
#  array([-231.        , -215.23333333, -199.46666667, -183.7       ,
#         -167.93333333, -152.16666667, -136.4       , -120.63333333,
#         -104.86666667,  -89.1       ,  -73.33333333,  -57.56666667,
#          -41.8       ,  -26.03333333,  -10.26666667,    5.5       ,
#           21.26666667,   37.03333333,   52.8       ,   68.56666667,
#           84.33333333,  100.1       ,  115.86666667,  131.63333333,
#          147.4       ,  163.16666667,  178.93333333,  194.7       ,
#          210.46666667,  226.23333333,  242.        ]),
#  <a list of 30 Patch objects>)

# %%
sb.distplot(arr,bins=50)

# %%
import scipy.stats as scstat

# %%
fn = scstat.gaussian_kde(arr)

# %%
fn(100)
# Out:
# array([0.00128024])

# %%
arr2 = np.hstack([arr,np.random.randint(50,120,20)])

# %%
plt.hist(arr2,bins=30)
# Out:
# (array([ 1.,  1.,  1.,  1.,  3.,  2.,  4.,  4.,  1.,  5.,  5.,  7.,  5.,
#          8.,  8., 12.,  6.,  9.,  8.,  4.,  2.,  6.,  2.,  5.,  4.,  0.,
#          5.,  0.,  0.,  1.]),
#  array([-231.        , -215.23333333, -199.46666667, -183.7       ,
#         -167.93333333, -152.16666667, -136.4       , -120.63333333,
#         -104.86666667,  -89.1       ,  -73.33333333,  -57.56666667,
#          -41.8       ,  -26.03333333,  -10.26666667,    5.5       ,
#           21.26666667,   37.03333333,   52.8       ,   68.56666667,
#           84.33333333,  100.1       ,  115.86666667,  131.63333333,
#          147.4       ,  163.16666667,  178.93333333,  194.7       ,
#          210.46666667,  226.23333333,  242.        ]),
#  <a list of 30 Patch objects>)

# %%
fn = scstat.gaussian_kde(arr2)

# %%
fn(80)
# Out:
# array([0.00284649])

# %%
fn(100)
# Out:
# array([0.00240466])

# %%
x = np.linspace(-300,300,100)

# %%
plt.plot(x,fn(x))

# %%
ls = []
for i in range(-300,300):
    p = fn(i)
    a = [i]*int(p[0]*1000)
    ls.extend(a)

# %%
x=np.linspace(-300,300,len(ls))

# %%
plt.hist(ls,bins=30)
# Out:
# (array([12., 12., 12., 12., 12., 15., 24., 24., 24., 28., 36., 36., 36.,
#         37., 44., 48., 45., 36., 36., 36., 29., 24., 24., 24., 23., 12.,
#         12., 12., 12., 12.]),
#  array([-169.        , -157.06666667, -145.13333333, -133.2       ,
#         -121.26666667, -109.33333333,  -97.4       ,  -85.46666667,
#          -73.53333333,  -61.6       ,  -49.66666667,  -37.73333333,
#          -25.8       ,  -13.86666667,   -1.93333333,   10.        ,
#           21.93333333,   33.86666667,   45.8       ,   57.73333333,
#           69.66666667,   81.6       ,   93.53333333,  105.46666667,
#          117.4       ,  129.33333333,  141.26666667,  153.2       ,
#          165.13333333,  177.06666667,  189.        ]),
#  <a list of 30 Patch objects>)

# %%
fn2 = scstat.gaussian_kde(ls)

# %%
plt.plot(x,fn(x))

# %%
from scipy.stats import norm
import numpy as np
norm.cdf(np.array([1,-1., 0, 1, 3, 4, -2, 6]))
# Out:
# array([0.84134475, 0.15865525, 0.5       , 0.84134475, 0.9986501 ,
#        0.99996833, 0.02275013, 1.        ])

# %%
norm.pdf(np.array([1,-1., 0, 1, 3, 4, -2, 6]))
# Out:
# array([2.41970725e-01, 2.41970725e-01, 3.98942280e-01, 2.41970725e-01,
#        4.43184841e-03, 1.33830226e-04, 5.39909665e-02, 6.07588285e-09])

# %%
norm.entropy(np.array([1,-1., 0, 1, 3, 4, -2, 6]))
# Out:
# array([1.41893853, 1.41893853, 1.41893853, 1.41893853, 1.41893853,
#        1.41893853, 1.41893853, 1.41893853])
