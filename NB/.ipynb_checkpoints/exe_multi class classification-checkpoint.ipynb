# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("class_exe.csv")

# %%
df.head()
# Out:
#     A  B  C    D  E  Target
# 0   5  2  3  526  1       2
# 1  15  1  3  338  2       2
# 2  18  3  3  605  2       3
# 3  18  2  5  734  1       3
# 4   7  2  2  137  2       2

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Target'],axis=1), df['Target'], test_size=0.33, random_state=42)

# %%
import sklearn.linear_model as lin
import sklearn.naive_bayes as nb

# %%
#model = lin.LogisticRegression(multi_class='multinomial',solver='lbfgs')
model = nb.GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pred =model.predict(X_test)

# %%
import sklearn.metrics as met

# %%
met.confusion_matrix(y_test,pred)
# Out:
# array([[104,   0,   0],
#        [  0,  75,  77],
#        [ 76,  82, 246]])

# %%
print(met.classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      1.00      0.73       104
#            2       0.48      0.49      0.49       152
#            3       0.76      0.61      0.68       404
#
#    micro avg       0.64      0.64      0.64       660
#    macro avg       0.61      0.70      0.63       660
# weighted avg       0.67      0.64      0.64       660
